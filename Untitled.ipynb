# %%
[32, 64, 96, 128, 160, 192, 224, 256, 288, 320, 352, 384, 416 ,448 ,480 ,512 ,544 ,576) 608 640 672 704 736 768 800 832 864 896 928 960 992 1024
--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence  32
224

Total Implementation time:
0.0003
0.0003,0.0004,0.0011,0.0027,0.0064 ,0.0126,0.0229,0.0391,
                0.0591,0.0840,0.1049,0.1311,0.1438,0.1685,0.1960,0.3884
--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 64
704

Total Implementation time:
0.0004

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 96
1728

Total Implementation time:
0.0011

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 128
3584

Total Implementation time:
0.0027

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 160
7040

Total Implementation time:
0.0064
 192, 224, 256, 288, 320, 352, 384, 416 ,448 ,480 ,512 ,544 ,576

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence  192
                 

Total Implementation time:
0.0126

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 224
19488
0.0003,0.0004,0.0003,0.0011,0.0027,0.0064 ,0.0126,0.0229,0.0391,
                0.0591,0.0840,0.1049,0.1311,0.1438,0.1685,0.1960,0.3884
Total Implementation time:
0.0229

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 256
29696
            
Total Implementation time:
0.0391

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 288
41472

Total Implementation time:
0.0591    

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 320
52800

Total Implementation time:
0.0840         1728,3584,7040,12288,19488,29696,41472,52800,60192,69120,69888,76608,86
12288

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 352
60192
                                352, 384, 416 ,448 ,480 ,512 ,544 ,576
Total Implementation time:
0.1049
0.0003,0.0004,0.0003,0.0011,0.0027,0.0064 ,0.0126,0.0229,0.0391,
                0.0591,0.0840,0.1049,0.1311,0.1438,0.1685,0.1960,0.3884
--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence 384
69120

Total Implementation time:
0.1311

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence  416
69888

Total Implementation time:
0.1438

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence  448
76608

Total Implementation time:
0.1685

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence  480
83040

Total Implementation time:
0.1960

--------------- Inside Gauss Siedel Function-------------------------------------------------------
Total iterations for Gauss methods convergence  512
156160

Total Implementation time:
0.3884
slurmstepd: *** JOB 1286168 ON b006 CANCELLED AT 2017-05-22T16:25:05 DUE TO TIME LIMIT ***

# %%
Gauss-Seidel X 545 Y 545 Px 2 Py 4 Iter 2901 ComputationTime 0.790258 TotalTime 1.654769 midpoint 3144.658134

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors
import math
import matplotlib
import matplotlib.ticker as ticker

import numpy as np

# %%
fig = plt.figure(figsize=(30, 2))
N=np.array([32, 64, 96, 128, 160, 192, 224, 256, 288, 320, 352, 384, 416 ,448 ,480 ,512 ])
time= np.array([0.0003,0.0004,0.0011,0.0027,0.0064 ,0.0126,0.0229,0.0391,
                0.0591,0.0840,0.1049,0.1311,0.1438,0.1685,0.1960,0.3884])
Iterations = np.array([224,704,1728,3584,7040,12288,19488,29696,41472,52800,60192,69120,69888,76608,83040,156160])
fig, ax = plt.subplots()
ax.plot(N, time,color = 'brown',linestyle='-',marker="o",label="Time Vs Array Size ")
#ax.plot(N, Iterations,color = 'orange',linestyle='-',marker="^",label="Number of Interations Vs Array Size")
#ax.plot_date(x_axis[0:actual.shape[0]], actual.reshape(actual.shape[0],1)[0:actual.shape[0]],color='goldenrod',linestyle='-',label="Actual Values")
plt.legend(bbox_to_anchor=(0.01, 0.98), loc=2, borderaxespad=0.,fontsize='x-large')

ax.set_yscale('log')
ax.set_xscale('log')
#ax.set_xticks(np.arange(0, 1, 0.1))
#ax.set_yticks(np.arange(0, 1., 0.1))
ax.grid(True)

plt.tight_layout()
plt.ylabel("Execution Time",fontweight='bold')
plt.xlabel("Array Size N",fontweight='bold')

plt.title("Sequential Execution Time Plot",fontweight='bold')
plt.show()

# %%
fig = plt.figure(figsize=(30, 2))
N=np.array([32, 64, 96, 128, 160, 192, 224, 256, 288, 320, 352, 384, 416 ,448 ,480 ,512 ])
time= np.array([0.0003,0.0004,0.0011,0.0027,0.0064 ,0.0126,0.0229,0.0391,
                0.0591,0.0840,0.1049,0.1311,0.1438,0.1685,0.1960,0.3884])
Iterations = np.array([224,704,1728,3584,7040,12288,19488,29696,41472,52800,60192,69120,69888,76608,83040,156160])
fig, ax = plt.subplots()
#ax.plot(N, time,color = 'brown',linestyle='-',marker="o",label="Time Vs Array Size ")
ax.plot(N, Iterations,color = 'orange',linestyle='-',marker="^",label="Iteration size Vs Array Size")
#ax.plot_date(x_axis[0:actual.shape[0]], actual.reshape(actual.shape[0],1)[0:actual.shape[0]],color='goldenrod',linestyle='-',label="Actual Values")
plt.legend(bbox_to_anchor=(0.01, 0.98), loc=2, borderaxespad=0.,fontsize='x-large')

ax.set_yscale('log')
ax.set_xscale('log')
ax.grid(True)

plt.tight_layout()
plt.ylabel("Iterations Steps to Solution",fontweight='bold')
plt.xlabel("Array Size N",fontweight='bold')

plt.title("Sequential Execution Steps to Solution",fontweight='bold')
plt.show()

# %%
## 448
Gauss-Seidel X 448 Y 448 Px 2 Py 4 Iter 2401 ComputationTime 0.429891 TotalTime 0.916852 midpoint 2683.194597
Gauss-Seidel X 448 Y 448 Px 3 Py 4 Iter 2401 ComputationTime 0.300062 TotalTime 0.652606 midpoint 1978.361686
Gauss-Seidel X 448 Y 448 Px 4 Py 4 Iter 2501 ComputationTime 0.240686 TotalTime 0.523791 midpoint 1736.309467
Gauss-Seidel X 448 Y 448 Px 4 Py 5 Iter 2401 ComputationTime 0.187096 TotalTime 0.419511 midpoint 1662.334803
Gauss-Seidel X 448 Y 448 Px 4 Py 6 Iter 2401 ComputationTime 0.154132 TotalTime 0.351006 midpoint 1678.713751
Gauss-Seidel X 448 Y 448 Px 4 Py 7 Iter 2401 ComputationTime 0.130895 TotalTime 0.316107 midpoint 1697.033853
Gauss-Seidel X 448 Y 448 Px 4 Py 8 Iter 2401 ComputationTime 0.112480 TotalTime 0.276263 midpoint 1715.421954

### 480


Gauss-Seidel X 480 Y 480 Px 2 Py 4 Iter 2501 ComputationTime 0.513698 TotalTime 1.085178 midpoint 2835.834761
Gauss-Seidel X 480 Y 480 Px 4 Py 3 Iter 2601 ComputationTime 0.380511 TotalTime 0.813370 midpoint 1695.588225
Gauss-Seidel X 641 Y 641 Px 4 Py 3 Iter 3401 ComputationTime 0.876692 TotalTime 1.849515 midpoint 2070.177966
Gauss-Seidel X 641 Y 641 Px 4 Py 4 Iter 3601 ComputationTime 0.710089 TotalTime 1.511720 midpoint 2134.944382
Gauss-Seidel X 641 Y 641 Px 4 Py 5 Iter 3401 ComputationTime 0.541780 TotalTime 1.182478 midpoint 2075.137205
Gauss-Seidel X 641 Y 641 Px 4 Py 6 Iter 3401 ComputationTime 0.453492 TotalTime 0.996345 midpoint 2081.766078
Gauss-Seidel X 641 Y 641 Px 4 Py 7 Iter 3401 ComputationTime 0.389836 TotalTime 0.887751 midpoint 2089.648084
Gauss-Seidel X 641 Y 641 Px 4 Py 8 Iter 3401 ComputationTime 0.340677 TotalTime 0.779795 midpoint 2098.746497

## 673
Gauss-Seidel X 673 Y 673 Px 2 Py 4 Iter 3501 ComputationTime 1.455493 TotalTime 3.019148 midpoint 3774.110432
Gauss-Seidel X 673 Y 673 Px 4 Py 3 Iter 3601 ComputationTime 1.022694 TotalTime 2.148985 midpoint 2148.516106
Gauss-Seidel X 673 Y 673 Px 4 Py 4 Iter 3701 ComputationTime 0.809422 TotalTime 1.722066 midpoint 2207.679246
Gauss-Seidel X 673 Y 673 Px 4 Py 5 Iter 3601 ComputationTime 0.632663 TotalTime 1.371519 midpoint 2149.395769
Gauss-Seidel X 673 Y 673 Px 4 Py 6 Iter 3601 ComputationTime 0.538098 TotalTime 1.186312 midpoint 2153.366356
Gauss-Seidel X 673 Y 673 Px 4 Py 7 Iter 3601 ComputationTime 0.461717 TotalTime 1.024267 midpoint 2160.405231
Gauss-Seidel X 673 Y 673 Px 4 Py 8 Iter 3601 ComputationTime 0.399453 TotalTime 0.908320 midpoint 2169.138183

# %%
513,545,641,673
fig = plt.figure(figsize=(30, 2))
N=np.array([8,12,16,20,24,28,32])
weak= np.array([0.645311,0.439334,0.362491,0.289834,0.239754,0.204495,0.171205 ])
weak2 = np.array([0.790258,0.555812,0.451565,0.328643,0.279953,0.237821,0.208319 ])
weak4 = np.array([1.266240,0.876692,0.710089,0.541780,0.453492,0.389836,0.340677])
weak5 = np.array([1.455493,1.022694,0.809422,0.632663,0.538098,0.461717,0.399453])
weak3 = np.array([1,1,1,1,1,1,1 ])
fig, ax = plt.subplots()
ax = fig.gca()
ax.plot(N, weak3,color = 'black',linestyle='-',marker="^",label="Ideal")
#ax.plot(N, time,color = 'brown',linestyle='-',marker="o",label="Time Vs Array Size ")
ax.plot(N, weak,color = 'deepskyblue',linestyle='--',marker="o",label="problem size 673")
#ax.plot_date(x_axis[0:actual.shape[0]], actual.reshape(actual.shape[0],1)[0:actual.shape[0]],color='goldenrod',linestyle='-',label="Actual Values")
ax.plot(N, weak2,color = 'brown',linestyle='--',marker="^",label="problem size 524")

ax.plot(N, weak4,color = 'lime',linestyle='-',marker="^",label="problem size 640")
ax.plot(N, weak5,color = 'orange',linestyle='-',marker="*",label="problem size 640")
plt.legend(bbox_to_anchor=(1.01, 0.98), loc=2, borderaxespad=0.,fontsize='x-large')

#ax.set_yscale('log')
#ax.set_xscale('log')
#matplotlib.pyplot.grid(True, which="both")
#ax.set_xticks(np.arange(0, 8, 10))
#ax.set_yticks(numpy.arange(0, 1., 0.1))
#ax.set_yticks(numpy.arange(0, 1., 0.1)

#ax.set_xticks(np.arange(0, 10, 10))
#ax.set_yticks(np.arange(0, 3, 0.1))
ax.grid(True)
plt.tight_layout()
plt.ylabel("Efficiency",fontweight='bold')
plt.xlabel("Nodes",fontweight='bold')
plt.title("Efficiency plot",fontweight='bold')
#plt.grid()              
plt.show()

# %%
0.1960

0.3884

fig = plt.figure(figsize=(30, 2))
N=np.array([8,12,16,20,24,28,32])
#speeded = np.array([0.5,1.0,1.5,2.0,2.5,3.0,3.5])
speed= np.array([0.1685/0.645311,0.1685/0.439334,0.1685/0.362491,0.1685/0.289834,0.1685/0.239754,0.1685/0.204495,0.1685/0.171205 ]) #448
speed2 = np.array([0.1960/0.513698,
0.1960/0.380511,
0.1960/0.302547,
0.1960/0.232682,
0.1960/0.191982,
0.1960/0.163669,
0.1960/0.140694 ])
speed3 = np.array([0.3884/0.645311,
 0.3884/0.439334 , 
    0.3884/0.362491,
    0.3884/0.289834,
    0.3884/0.239754,
    0.3884/0.204495,
0.3884/0.171205])
#speed4 = np.array([1.455493,1.022694,0.809422,0.632663,0.538098,0.461717,0.399453])

fig, ax = plt.subplots()

#ax.plot( N,speeded,color = 'black',linestyle='-',marker="^",label="Ideal")
#ax.plot(N, time,color = 'brown',linestyle='-',marker="o",label="Time Vs Array Size ")
ax.plot(N,speed,color = 'deepskyblue',linestyle='--',marker="o",label="problem size 448")
#ax.plot_date(x_axis[0:actual.shape[0]], actual.reshape(actual.shape[0],1)[0:actual.shape[0]],color='goldenrod',linestyle='-',label="Actual Values")
ax.plot(N,speed2,color = 'brown',linestyle='--',marker="^",label="problem size 480")

ax.plot(N,speed3, color = 'lime',linestyle='-',marker="^",label="problem size 512")
#ax.plot(N,speed3,color = 'orange',linestyle='-',marker="*",label="problem size 640")
plt.legend(bbox_to_anchor=(1.01, 0.98), loc=2, borderaxespad=0.,fontsize='x-large')

#ax.set_yscale('log')
#ax.set_xscale('log')
#matplotlib.pyplot.grid(True, which="both")

#ax.set_yticks(numpy.arange(0, 1., 0.1))
#ax.set_yticks(numpy.arange(0, 1., 0.1)

#ax.set_xticks(np.arange(0, 10, 10))
#ax.set_yticks(np.arange(0, 3, 0.1))
ax.grid(True)
plt.tight_layout()
plt.ylabel("Speed up",fontweight='bold')
plt.xlabel("Nodes",fontweight='bold')
plt.title("Speed up plot",fontweight='bold')
             
plt.show()
